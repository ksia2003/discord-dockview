# %% [markdown]
# # DockView Notebook Sample
#
# A tiny Jupyter notebook with a markdown cell and a code cell + output.

# %%
print('squares:', [n*n for n in range(5)])
# Out:
# squares: [0, 1, 4, 9, 16]
